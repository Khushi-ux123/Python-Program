# %%
import pandas as pd
data=pd.read_csv('C:/Users/Dell/Downloads/country_wise_latest.csv')
print(data)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.max()
# Out:
# Country/Region                   Zimbabwe
# Confirmed                         4290259
# Deaths                             148011
# Recovered                         1846641
# Active                            2816444
# New cases                           56336
# New deaths                           1076
# New recovered                       33728
# Deaths / 100 Cases                  28.56
# Recovered / 100 Cases               100.0
# Deaths / 100 Recovered                inf
# Confirmed last week               3834677
# 1 week change                      455582
# 1 week % increase                  226.32
# WHO Region                Western Pacific
# dtype: object

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
info=data.sort_values(by=['Deaths'],ascending=False)
info.head(3)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# 23          614          33728                3.59                  75.61
# 177           7              3               15.19                   0.48
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 173                   11.16              3834677         455582
# 23                     4.74              2118646         323729
# 177                 3190.26               296944           4764
#
#      1 week % increase WHO Region
# 173              11.88   Americas
# 23               15.28   Americas
# ...

# %%
data['Deaths'].mean()
# Out:
# np.float64(3497.51871657754)

# %%
data['Deaths'].mode()
# Out:
# 0    0
# Name: Deaths, dtype: int64

# %%
data['Deaths'].median()
# Out:
# np.float64(108.0)

# %%
data.describe()
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
# ...

# %%
data.groupby('Deaths').sum()
# Out:
#                                            Country/Region  Confirmed  \
# Deaths
# 0       BhutanCambodiaDominicaEritreaFijiGreenlandGren...       1717
# 1                      BurundiLiechtensteinWestern Sahara        474
# 2                                    BelizeBotswanaUganda       1915
# 3                               Antigua and BarbudaBrunei        227
# 4                                                  Monaco        116
# ...                                                   ...        ...
# 35112                                               Italy     246286
# 44022                                              Mexico     395489
# 45844                                      United Kingdom     301708
# 87618                                              Brazil    2442375
# 148011                                                 US    4290259
#
#         Recovered   Active  New cases  New deaths  New recovered  \
# Deaths
# ...

# %%
data.drop(columns='Active')
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  New cases  New deaths  \
# 0           Afghanistan      36263    1269      25198        106          10
# 1               Albania       4880     144       2745        117           6
# 2               Algeria      27973    1163      18837        616           8
# 3               Andorra        907      52        803         10           0
# 4                Angola        950      41        242         18           1
# ..                  ...        ...     ...        ...        ...         ...
# 182  West Bank and Gaza      10621      78       3752        152           2
# 183      Western Sahara         10       1          8          0           0
# 184               Yemen       1691     483        833         10           4
# 185              Zambia       4552     140       2815         71           1
# 186            Zimbabwe       2704      36        542        192           2
#
# ...

# %%
data.Recovered
# Out:
# 0      25198
# 1       2745
# 2      18837
# 3        803
# 4        242
#        ...
# 182     3752
# 183        8
# 184      833
# 185     2815
# 186      542
# Name: Recovered, Length: 187, dtype: int64

# %%
getattr(data, "Deaths / 100 Cases")
# Out:
# 0       3.50
# 1       2.95
# 2       4.16
# 3       5.73
# 4       4.32
#        ...
# 182     0.73
# 183    10.00
# 184    28.56
# 185     3.08
# 186     1.33
# Name: Deaths / 100 Cases, Length: 187, dtype: float64

# %%
data[["Country/Region","Deaths"]]
# Out:
#          Country/Region  Deaths
# 0           Afghanistan    1269
# 1               Albania     144
# 2               Algeria    1163
# 3               Andorra      52
# 4                Angola      41
# ..                  ...     ...
# 182  West Bank and Gaza      78
# 183      Western Sahara       1
# 184               Yemen     483
# 185              Zambia     140
# 186            Zimbabwe      36
#
# [187 rows x 2 columns]

# %%
data[1:4]
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
#
#    1 week % increase WHO Region
# 1              17.00     Europe
# 2              18.07     Africa
# 3               2.60     Europe

# %%
data[0:]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data[:11]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.iloc[3,2]
# Out:
# np.int64(52)

# %%
data.iloc[[0,1],1]
# Out:
# 0    36263
# 1     4880
# Name: Confirmed, dtype: int64

# %%
data.iloc[1: 3, 2: 4]
# Out:
#    Deaths  Recovered
# 1     144       2745
# 2    1163      18837

# %%
data.drop([data.index[1], data.index[2]])
# Out:
#           Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0            Afghanistan      36263    1269      25198    9796        106
# 3                Andorra        907      52        803      52         10
# 4                 Angola        950      41        242     667         18
# 5    Antigua and Barbuda         86       3         65      18          4
# 6              Argentina     167416    3059      72575   91782       4890
# ..                   ...        ...     ...        ...     ...        ...
# 182   West Bank and Gaza      10621      78       3752    6791        152
# 183       Western Sahara         10       1          8       1          0
# 184                Yemen       1691     483        833     375         10
# 185               Zambia       4552     140       2815    1597         71
# 186             Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.transpose
# Out:
# <bound method DataFrame.transpose of          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
# ...

# %%
 data.drop_duplicates('WHO Region')
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 5   Antigua and Barbuda         86       3         65      18          4
# 8             Australia      15303     167       9311    5825        368
# 13           Bangladesh     226225    2965     125683   97577       2772
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0           10             18                3.50                  69.49
# 1            6             63                2.95                  56.25
# 2            8            749                4.16                  67.34
# 5            0              5                3.49                  75.58
# 8            6            137                1.09                  60.84
# ...

# %%
data.count()
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
data.hist('Deaths')
# Out:
# array([[<Axes: title={'center': 'Deaths'}>]], dtype=object)

# %%
for i, j in data.iterrows():   
    print(i, j)
# Out:
# 0 Country/Region                      Afghanistan
# Confirmed                                 36263
# Deaths                                     1269
# Recovered                                 25198
# Active                                     9796
# New cases                                   106
# New deaths                                   10
# New recovered                                18
# Deaths / 100 Cases                          3.5
# Recovered / 100 Cases                     69.49
# Deaths / 100 Recovered                     5.04
# Confirmed last week                       35526
# 1 week change                               737
# 1 week % increase                          2.07
# WHO Region                Eastern Mediterranean
# Name: 0, dtype: object
# 1 Country/Region            Albania
# Confirmed                    4880
# Deaths                        144
# Recovered                    2745
# Active                       1991
# New cases                     117
# ...

# %%
pd.melt(data)
# Out:
#             variable                  value
# 0     Country/Region            Afghanistan
# 1     Country/Region                Albania
# 2     Country/Region                Algeria
# 3     Country/Region                Andorra
# 4     Country/Region                 Angola
# ...              ...                    ...
# 2800      WHO Region  Eastern Mediterranean
# 2801      WHO Region                 Africa
# 2802      WHO Region  Eastern Mediterranean
# 2803      WHO Region                 Africa
# 2804      WHO Region                 Africa
#
# [2805 rows x 2 columns]

# %%
data.isin(range(1000,2000))
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False    True      False   False      False
# 1             False      False   False      False    True      False
# 2             False      False    True      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False       True   False      False   False      False
# 185           False      False   False      False    True      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...
